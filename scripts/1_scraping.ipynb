# %% [markdown]
# <a href="https://colab.research.google.com/github/srujanay18/DS3001-FinalProject/blob/main/scripts/1_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
from time import sleep

def download_inat_images(species_name, max_images=100, delay=1):
    """
    Downloads images from iNaturalist for a given species name.
    Only includes research-grade observations with photos.
    """
    folder_name = species_name.replace(" ", "_")
    os.makedirs(folder_name, exist_ok=True)

    base_url = "https://api.inaturalist.org/v1/observations"
    params = {
        "taxon_name": species_name,
        "quality_grade": "research",
        "has": "photos",
        "per_page": 100,   # max per page
        "page": 1
    }

    downloaded = 0
    seen_urls = set()

    while downloaded < max_images:
        print(f"Fetching page {params['page']} for {species_name}...")
        response = requests.get(base_url, params=params)
        if response.status_code != 200:
            print("Error fetching data:", response.status_code)
            break

        data = response.json().get("results", [])
        if not data:
            print("No more results found.")
            break

        for obs in data:
            if "photos" not in obs or not obs["photos"]:
                continue
            img_url = obs["photos"][0]["url"].replace("square", "medium")
            if img_url in seen_urls:
                continue
            seen_urls.add(img_url)

            try:
                img_data = requests.get(img_url).content
                img_path = os.path.join(folder_name, f"{downloaded+1:04}.jpg")
                with open(img_path, "wb") as f:
                    f.write(img_data)
                downloaded += 1
                print(f"Saved: {img_path}")
                if downloaded >= max_images:
                    break
                sleep(delay)  # polite delay to avoid rate limits
            except Exception as e:
                print("Failed to download image:", e)
                continue

        params["page"] += 1

    print(f"\n✅ Downloaded {downloaded} images for {species_name}\n")

# Example usage:
download_inat_images("Harmonia axyridis", max_images=120)
download_inat_images("Coccinella novemnotata", max_images=120)
# Out:
# Fetching page 1 for Harmonia axyridis...
# Saved: Harmonia_axyridis/0001.jpg
# Saved: Harmonia_axyridis/0002.jpg
# Saved: Harmonia_axyridis/0003.jpg
# Saved: Harmonia_axyridis/0004.jpg
# Saved: Harmonia_axyridis/0005.jpg
# Saved: Harmonia_axyridis/0006.jpg
# Saved: Harmonia_axyridis/0007.jpg
# Saved: Harmonia_axyridis/0008.jpg
# Saved: Harmonia_axyridis/0009.jpg
# Saved: Harmonia_axyridis/0010.jpg
# Saved: Harmonia_axyridis/0011.jpg
# Saved: Harmonia_axyridis/0012.jpg
# Saved: Harmonia_axyridis/0013.jpg
# Saved: Harmonia_axyridis/0014.jpg
# Saved: Harmonia_axyridis/0015.jpg
# Saved: Harmonia_axyridis/0016.jpg
# Saved: Harmonia_axyridis/0017.jpg
# Saved: Harmonia_axyridis/0018.jpg
# Saved: Harmonia_axyridis/0019.jpg
# Saved: Harmonia_axyridis/0020.jpg
# Saved: Harmonia_axyridis/0021.jpg
# Saved: Harmonia_axyridis/0022.jpg
# Saved: Harmonia_axyridis/0023.jpg
# Saved: Harmonia_axyridis/0024.jpg
# Saved: Harmonia_axyridis/0025.jpg
# Saved: Harmonia_axyridis/0026.jpg
# Saved: Harmonia_axyridis/0027.jpg
# Saved: Harmonia_axyridis/0028.jpg
# Saved: Harmonia_axyridis/0029.jpg
# Saved: Harmonia_axyridis/0030.jpg
# Saved: Harmonia_axyridis/0031.jpg
# Saved: Harmonia_axyridis/0032.jpg
# Saved: Harmonia_axyridis/0033.jpg
# Saved: Harmonia_axyridis/0034.jpg
# Saved: Harmonia_axyridis/0035.jpg
# Saved: Harmonia_axyridis/0036.jpg
# Saved: Harmonia_axyridis/0037.jpg
# Saved: Harmonia_axyridis/0038.jpg
# Saved: Harmonia_axyridis/0039.jpg
# Saved: Harmonia_axyridis/0040.jpg
# Saved: Harmonia_axyridis/0041.jpg
# Saved: Harmonia_axyridis/0042.jpg
# Saved: Harmonia_axyridis/0043.jpg
# Saved: Harmonia_axyridis/0044.jpg
# Saved: Harmonia_axyridis/0045.jpg
# Saved: Harmonia_axyridis/0046.jpg
# Saved: Harmonia_axyridis/0047.jpg
# Saved: Harmonia_axyridis/0048.jpg
# Saved: Harmonia_axyridis/0049.jpg
# Saved: Harmonia_axyridis/0050.jpg
# Saved: Harmonia_axyridis/0051.jpg
# Saved: Harmonia_axyridis/0052.jpg
# Saved: Harmonia_axyridis/0053.jpg
# Saved: Harmonia_axyridis/0054.jpg
# Saved: Harmonia_axyridis/0055.jpg
# Saved: Harmonia_axyridis/0056.jpg
# Saved: Harmonia_axyridis/0057.jpg
# Saved: Harmonia_axyridis/0058.jpg
# Saved: Harmonia_axyridis/0059.jpg
# Saved: Harmonia_axyridis/0060.jpg
# Saved: Harmonia_axyridis/0061.jpg
# Saved: Harmonia_axyridis/0062.jpg
# Saved: Harmonia_axyridis/0063.jpg
# Saved: Harmonia_axyridis/0064.jpg
# Saved: Harmonia_axyridis/0065.jpg
# Saved: Harmonia_axyridis/0066.jpg
# Saved: Harmonia_axyridis/0067.jpg
# Saved: Harmonia_axyridis/0068.jpg
# Saved: Harmonia_axyridis/0069.jpg
# Saved: Harmonia_axyridis/0070.jpg
# Saved: Harmonia_axyridis/0071.jpg
# Saved: Harmonia_axyridis/0072.jpg
# Saved: Harmonia_axyridis/0073.jpg
# Saved: Harmonia_axyridis/0074.jpg
# Saved: Harmonia_axyridis/0075.jpg
# Saved: Harmonia_axyridis/0076.jpg
# Saved: Harmonia_axyridis/0077.jpg
# Saved: Harmonia_axyridis/0078.jpg
# Saved: Harmonia_axyridis/0079.jpg
# Saved: Harmonia_axyridis/0080.jpg
# Saved: Harmonia_axyridis/0081.jpg
# Saved: Harmonia_axyridis/0082.jpg
# Saved: Harmonia_axyridis/0083.jpg
# Saved: Harmonia_axyridis/0084.jpg
# Saved: Harmonia_axyridis/0085.jpg
# Saved: Harmonia_axyridis/0086.jpg
# Saved: Harmonia_axyridis/0087.jpg
# Saved: Harmonia_axyridis/0088.jpg
# Saved: Harmonia_axyridis/0089.jpg
# Saved: Harmonia_axyridis/0090.jpg
# Saved: Harmonia_axyridis/0091.jpg
# Saved: Harmonia_axyridis/0092.jpg
# Saved: Harmonia_axyridis/0093.jpg
# Saved: Harmonia_axyridis/0094.jpg
# Saved: Harmonia_axyridis/0095.jpg
# Saved: Harmonia_axyridis/0096.jpg
# Saved: Harmonia_axyridis/0097.jpg
# Saved: Harmonia_axyridis/0098.jpg
# Saved: Harmonia_axyridis/0099.jpg
# Saved: Harmonia_axyridis/0100.jpg
# Fetching page 2 for Harmonia axyridis...
# Saved: Harmonia_axyridis/0101.jpg
# Saved: Harmonia_axyridis/0102.jpg
# Saved: Harmonia_axyridis/0103.jpg
# Saved: Harmonia_axyridis/0104.jpg
# Saved: Harmonia_axyridis/0105.jpg
# Saved: Harmonia_axyridis/0106.jpg
# Saved: Harmonia_axyridis/0107.jpg
# Saved: Harmonia_axyridis/0108.jpg
# Saved: Harmonia_axyridis/0109.jpg
# Saved: Harmonia_axyridis/0110.jpg
# Saved: Harmonia_axyridis/0111.jpg
# Saved: Harmonia_axyridis/0112.jpg
# Saved: Harmonia_axyridis/0113.jpg
# Saved: Harmonia_axyridis/0114.jpg
# Saved: Harmonia_axyridis/0115.jpg
# Saved: Harmonia_axyridis/0116.jpg
# Saved: Harmonia_axyridis/0117.jpg
# Saved: Harmonia_axyridis/0118.jpg
# Saved: Harmonia_axyridis/0119.jpg
# Saved: Harmonia_axyridis/0120.jpg
#
# ✅ Downloaded 120 images for Harmonia axyridis
#
# Fetching page 1 for Coccinella novemnotata...
# Saved: Coccinella_novemnotata/0001.jpg
# Saved: Coccinella_novemnotata/0002.jpg
# Saved: Coccinella_novemnotata/0003.jpg
# Saved: Coccinella_novemnotata/0004.jpg
# Saved: Coccinella_novemnotata/0005.jpg
# Saved: Coccinella_novemnotata/0006.jpg
# Saved: Coccinella_novemnotata/0007.jpg
# Saved: Coccinella_novemnotata/0008.jpg
# Saved: Coccinella_novemnotata/0009.jpg
# Saved: Coccinella_novemnotata/0010.jpg
# Saved: Coccinella_novemnotata/0011.jpg
# Saved: Coccinella_novemnotata/0012.jpg
# Saved: Coccinella_novemnotata/0013.jpg
# Saved: Coccinella_novemnotata/0014.jpg
# Saved: Coccinella_novemnotata/0015.jpg
# Saved: Coccinella_novemnotata/0016.jpg
# Saved: Coccinella_novemnotata/0017.jpg
# Saved: Coccinella_novemnotata/0018.jpg
# Saved: Coccinella_novemnotata/0019.jpg
# Saved: Coccinella_novemnotata/0020.jpg
# Saved: Coccinella_novemnotata/0021.jpg
# Saved: Coccinella_novemnotata/0022.jpg
# Saved: Coccinella_novemnotata/0023.jpg
# Saved: Coccinella_novemnotata/0024.jpg
# Saved: Coccinella_novemnotata/0025.jpg
# Saved: Coccinella_novemnotata/0026.jpg
# Saved: Coccinella_novemnotata/0027.jpg
# Saved: Coccinella_novemnotata/0028.jpg
# Saved: Coccinella_novemnotata/0029.jpg
# Saved: Coccinella_novemnotata/0030.jpg
# Saved: Coccinella_novemnotata/0031.jpg
# Saved: Coccinella_novemnotata/0032.jpg
# Saved: Coccinella_novemnotata/0033.jpg
# Saved: Coccinella_novemnotata/0034.jpg
# Saved: Coccinella_novemnotata/0035.jpg
# Saved: Coccinella_novemnotata/0036.jpg
# Saved: Coccinella_novemnotata/0037.jpg
# Saved: Coccinella_novemnotata/0038.jpg
# Saved: Coccinella_novemnotata/0039.jpg
# Saved: Coccinella_novemnotata/0040.jpg
# Saved: Coccinella_novemnotata/0041.jpg
# Saved: Coccinella_novemnotata/0042.jpg
# Saved: Coccinella_novemnotata/0043.jpg
# Saved: Coccinella_novemnotata/0044.jpg
# Saved: Coccinella_novemnotata/0045.jpg
# Saved: Coccinella_novemnotata/0046.jpg
# Saved: Coccinella_novemnotata/0047.jpg
# Saved: Coccinella_novemnotata/0048.jpg
# Saved: Coccinella_novemnotata/0049.jpg
# Saved: Coccinella_novemnotata/0050.jpg
# Saved: Coccinella_novemnotata/0051.jpg
# Saved: Coccinella_novemnotata/0052.jpg
# Saved: Coccinella_novemnotata/0053.jpg
# Saved: Coccinella_novemnotata/0054.jpg
# Saved: Coccinella_novemnotata/0055.jpg
# Saved: Coccinella_novemnotata/0056.jpg
# Saved: Coccinella_novemnotata/0057.jpg
# Saved: Coccinella_novemnotata/0058.jpg
# Saved: Coccinella_novemnotata/0059.jpg
# Saved: Coccinella_novemnotata/0060.jpg
# Saved: Coccinella_novemnotata/0061.jpg
# Saved: Coccinella_novemnotata/0062.jpg
# Saved: Coccinella_novemnotata/0063.jpg
# Saved: Coccinella_novemnotata/0064.jpg
# Saved: Coccinella_novemnotata/0065.jpg
# Saved: Coccinella_novemnotata/0066.jpg
# Saved: Coccinella_novemnotata/0067.jpg
# Saved: Coccinella_novemnotata/0068.jpg
# Saved: Coccinella_novemnotata/0069.jpg
# Saved: Coccinella_novemnotata/0070.jpg
# Saved: Coccinella_novemnotata/0071.jpg
# Saved: Coccinella_novemnotata/0072.jpg
# Saved: Coccinella_novemnotata/0073.jpg
# Saved: Coccinella_novemnotata/0074.jpg
# Saved: Coccinella_novemnotata/0075.jpg
# Saved: Coccinella_novemnotata/0076.jpg
# Saved: Coccinella_novemnotata/0077.jpg
# Saved: Coccinella_novemnotata/0078.jpg
# Saved: Coccinella_novemnotata/0079.jpg
# Saved: Coccinella_novemnotata/0080.jpg
# Saved: Coccinella_novemnotata/0081.jpg
# Saved: Coccinella_novemnotata/0082.jpg
# Saved: Coccinella_novemnotata/0083.jpg
# Saved: Coccinella_novemnotata/0084.jpg
# Saved: Coccinella_novemnotata/0085.jpg
# Saved: Coccinella_novemnotata/0086.jpg
# Saved: Coccinella_novemnotata/0087.jpg
# Saved: Coccinella_novemnotata/0088.jpg
# Saved: Coccinella_novemnotata/0089.jpg
# Saved: Coccinella_novemnotata/0090.jpg
# Saved: Coccinella_novemnotata/0091.jpg
# Saved: Coccinella_novemnotata/0092.jpg
# Saved: Coccinella_novemnotata/0093.jpg
# Saved: Coccinella_novemnotata/0094.jpg
# Saved: Coccinella_novemnotata/0095.jpg
# Saved: Coccinella_novemnotata/0096.jpg
# Saved: Coccinella_novemnotata/0097.jpg
# Saved: Coccinella_novemnotata/0098.jpg
# Saved: Coccinella_novemnotata/0099.jpg
# Saved: Coccinella_novemnotata/0100.jpg
# Fetching page 2 for Coccinella novemnotata...
# Saved: Coccinella_novemnotata/0101.jpg
# Saved: Coccinella_novemnotata/0102.jpg
# Saved: Coccinella_novemnotata/0103.jpg
# Saved: Coccinella_novemnotata/0104.jpg
# Saved: Coccinella_novemnotata/0105.jpg
# Saved: Coccinella_novemnotata/0106.jpg
# Saved: Coccinella_novemnotata/0107.jpg
# Saved: Coccinella_novemnotata/0108.jpg
# Saved: Coccinella_novemnotata/0109.jpg
# Saved: Coccinella_novemnotata/0110.jpg
# Saved: Coccinella_novemnotata/0111.jpg
# Saved: Coccinella_novemnotata/0112.jpg
# Saved: Coccinella_novemnotata/0113.jpg
# Saved: Coccinella_novemnotata/0114.jpg
# Saved: Coccinella_novemnotata/0115.jpg
# Saved: Coccinella_novemnotata/0116.jpg
# Saved: Coccinella_novemnotata/0117.jpg
# Saved: Coccinella_novemnotata/0118.jpg
# Saved: Coccinella_novemnotata/0119.jpg
# Saved: Coccinella_novemnotata/0120.jpg
#
# ✅ Downloaded 120 images for Coccinella novemnotata

# %%
import os

folder_harmonia = "Harmonia_axyridis"
folder_coccinella = "Coccinella_novemnotata"

# Create zip files
os.system(f"zip -r {folder_harmonia}.zip {folder_harmonia}")
os.system(f"zip -r {folder_coccinella}.zip {folder_coccinella}")

print(f"Created {folder_harmonia}.zip and {folder_coccinella}.zip")
# Out:
# Created Harmonia_axyridis.zip and Coccinella_novemnotata.zip
